# %%
import nltk

# %%
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\Gauri\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
from nltk.corpus import gutenberg #word gutenberg not defined error for not writing this statement

# %%
hamlet = gutenberg.words('shakespeare-hamlet.txt')

# %%
print(len(hamlet))
# Out:
# 37360

# %%
nltk.download('punkt') #Lookup error because this package was not downloaded
hamlet_sentences = gutenberg.sents('shakespeare-hamlet.txt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Gauri\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
print(len(hamlet_sentences))
# Out:
# 3106

# %%
print(hamlet_sentences[1024])
# Out:
# ['What', 'say', 'you', '?']

# %%
print(len(gutenberg.paras('shakespeare-hamlet.txt')))
# Out:
# 950

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize('shakespeare-hamlet.txt')
# Out:
# ['shakespeare-hamlet.txt']

# %%
from nltk.text import Text

# %%
corpus = Text(gutenberg.words('shakespeare-hamlet.txt'))

# %%
gutenberg.words('shakespeare-hamlet.txt')
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Hamlet', 'by', ...]

# %%
gutenberg.sents('shakespeare-hamlet.txt')
# Out:
# [['[', 'The', 'Tragedie', 'of', 'Hamlet', 'by', 'William', 'Shakespeare', '1599', ']'], ['Actus', 'Primus', '.'], ...]

# %%
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer()

# %%
dir(ps)
# Out:
# ['MARTIN_EXTENSIONS',
#  'NLTK_EXTENSIONS',
#  'ORIGINAL_ALGORITHM',
#  '__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_abc_impl',
#  '_apply_rule_list',
#  '_contains_vowel',
#  '_ends_cvc',
#  '_ends_double_consonant',
#  '_has_positive_measure',
#  '_is_consonant',
#  '_measure',
#  '_replace_suffix',
#  '_step1a',
#  '_step1b',
#  '_step1c',
#  '_step2',
#  '_step3',
#  '_step4',
#  '_step5a',
#  '_step5b',
#  'mode',
#  'pool',
#  'stem',
#  'unicode_repr',
#  'vowels']

# %%
print(ps.stem('stemming'))
# Out:
# stem

# %%
nltk.download('averaged_perceptron_tagger') #error thrown during tagging as this needed to be downloaded.
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Gauri\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
for w in hamlet:
    rootword = ps.stem(w)
    tagged = nltk.pos_tag(rootword)
    print(tagged)
# Out:
# [('[', 'NN')]
# [('t', 'NN'), ('h', 'NN'), ('e', 'NN')]
# [('t', 'NN'), ('r', 'VBZ'), ('a', 'DT'), ('g', 'NN'), ('e', 'NN'), ('d', 'NN'), ('i', 'NN')]
# [('o', 'NN'), ('f', 'NN')]
# [('h', 'VB'), ('a', 'DT'), ('m', 'NN'), ('l', 'NN'), ('e', 'NN'), ('t', 'NN')]
# [('b', 'NN'), ('y', 'NN')]
# [('w', 'NN'), ('i', 'NN'), ('l', 'VBP'), ('l', 'NN'), ('i', 'NN'), ('a', 'DT'), ('m', 'NN')]
# [('s', 'NN'), ('h', 'VBZ'), ('a', 'DT'), ('k', 'NN'), ('e', 'NN'), ('s', 'NN'), ('p', 'NN'), ('e', 'VBZ'), ('a', 'DT'), ('r', 'NN')]
# [('1', 'CD'), ('5', 'CD'), ('9', 'CD'), ('9', 'CD')]
# [(']', 'NN')]
# [('a', 'DT'), ('c', 'JJ'), ('t', 'NN'), ('u', 'NN')]
# [('p', 'NN'), ('r', 'NN'), ('i', 'NN'), ('m', 'VBP'), ('u', 'NN')]
# [('.', '.')]
# [('s', 'JJ'), ('c', 'NN'), ('o', 'NN'), ('e', 'NN'), ('n', 'VBZ'), ('a', 'DT')]
# [('p', 'NN'), ('r', 'NN'), ('i', 'NN'), ('m', 'VBP'), ('a', 'DT')]
# [('.', '.')]
# [('e', 'NN'), ('n', 'CC'), ('t', 'NN'), ('e', 'NN'), ('r', 'NN')]
# ...

# %%
from nltk.stem import LancasterStemmer 
from nltk.stem import RegexpStemmer
from nltk.stem import SnowballStemmer

# %%
lstemmer = LancasterStemmer()
lstemmer.stem('dancing')
# Out:
# 'dant'

# %%
rstemmer=RegexpStemmer('ing')
rstemmer.stem('dancing')
# Out:
# 'danc'

# %%
rstemmer=RegexpStemmer('')
rstemmer.stem('dancing')
# Out:
# 'dancing'

# %%
ps.stem('dancing')
# Out:
# 'danc'

# %%
ps.stem('dancer')
# Out:
# 'dancer'

# %%
rstemmer=RegexpStemmer('ing') #rstemmer just removes the ing without verifying with the words.
rstemmer.stem('king')
# Out:
# 'k'

# %%
lstemmer.stem('king')
# Out:
# 'king'

# %%
ps.stem('king')
# Out:
# 'king'

# %%
#Accessing various corpora:
nltk.download('nps_chat') #corpus with 10000 posts
from nltk.corpus import nps_chat
chatroom = nps_chat.posts('10-19-20s_706posts.xml')
chatroom[124]
# Out:
# [nltk_data] Downloading package nps_chat to
# [nltk_data]     C:\Users\Gauri\AppData\Roaming\nltk_data...
# [nltk_data]   Package nps_chat is already up-to-date!
# ['hi', 'U64']

# %%
#snowball stemmer
from nltk.stem.snowball import GermanStemmer
stemmer = GermanStemmer()
stemmer.stem("Autobahnen")
# Out:
# 'autobahn'
